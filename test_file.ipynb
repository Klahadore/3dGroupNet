# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 3
#       1 import numpy as np
#       2 import tensorflow as tf
# ----> 3 from groupy.gconv.tensorflow_gconv.splitgconv3d import gconv3d, gconv3d_util
#       4 import groupy
#       5 import os
#
# File ~/Developer/3dfractureclass/groupy/gconv/tensorflow_gconv/splitgconv3d.py:3
#       1 import tensorflow as tf
# ----> 3 from groupy.gconv.make_gconv_indices import make_o_z3_indices, make_o_ot_indices, make_c4h_z3_indices, \
#       4     make_c4h_c4ht_indices, make_d4h_z3_indices, make_d4h_d4ht_indices, make_oh_z3_indices, make_oh_oht_indices, \
#       5     flatten_indices_3d
#       6 from groupy.gconv.tensorflow_gconv.transform_filter import transform_filter_3d_nhwc
#       9 def gconv3d(input, filter, strides, padding, gconv_indices, gconv_shape_info,
# ...
